# %% [markdown]
# <a href="https://colab.research.google.com/github/twyeh/university-physics/blob/%E5%8A%9B%E5%AD%B8/EinsteinPy_examples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 # !pip install einsteinpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.1/88.1 kB 4.1 MB/s eta 0:00:00
# ...

# %%
# !pip install ipympl

# %%
 # !pip install imagemagic
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 4.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Example 1
# Defining various parameters
# Initial position & momentum of the test partcle
#
# Spin of the Kerr Black Hole in metric_params
#
# Other solver parameters
#
# Note that, we are working in M-Units (
# ).

# %%
import numpy as np

from einsteinpy.geodesic import Timelike
from einsteinpy.plotting import StaticGeodesicPlotter

# %%
# Constant Radius Orbit
position = [4, np.pi / 3, 0.]
momentum = [0., 0.767851, 2.]
a = 0.99
steps = 400.
delta = 0.5

# %%
geod = Timelike(
    metric="Kerr",
    metric_params=(a,),
    position=position,
    momentum=momentum,
    steps=steps,
    delta=delta,
    return_cartesian=True
)

# %%
# %matplotlib inline
from einsteinpy.plotting import StaticGeodesicPlotter

sgpl = StaticGeodesicPlotter()
sgpl.plot(geod)
sgpl.show()

# %% [markdown]
# ## Example 2

# %%
from einsteinpy.hypersurface import SchwarzschildEmbedding
from einsteinpy.plotting import HypersurfacePlotter
from astropy import units as u

# %%
surface_obj = SchwarzschildEmbedding(5.927e23 * u.kg)

# %%
surface = HypersurfacePlotter(embedding=surface_obj, plot_type='surface')
surface.plot()
surface.show()
