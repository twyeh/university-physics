# %% [markdown]
# <a href="https://colab.research.google.com/github/twyeh/university-physics/blob/main/%E6%96%9C%E9%9D%A2%E9%81%8B%E5%8B%95%E5%AF%A6%E9%A9%97%E5%88%86%E6%9E%90_%E9%80%B2%E9%9A%8E%E7%89%88(20241010).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 載入基本模組

# %%
import matplotlib.pyplot as plt
import numpy as np
from scipy.optimize import curve_fit

# %% [markdown]
# # 斜面運動實驗
# ## 前言
# 在四百多年前，伽利略進行了斜面運動實驗，探討物體在斜面上運動時，位移與時間之間的關係，從而發現位移只與時間有關，而與速度無關。同時還發現，可以利用數學建立位移與時間的關係，進而為後續牛頓與笛卡爾的時間與空間的觀點奠定基礎。
# 在本次探究活動中，我們要利用探究式斜面運動實驗，重複伽利略當年的實驗，並利用python作為計算工具，分析實驗數據，以建立 位移-時間、速度-時間、加速度-時間的數學模型。
#
# 在前一篇基礎篇中，我們在計算平均速度及平均加速時假設了其對應的時間為中點時間，結果造成平均加速度的計算誤差偏大。顯示，該假設需要被改進。
#
# ## 問題
# 本實驗透過斜面運動探討下列三個問題：
#
#
# 1.   位置對時間的關係為何？
# 2.   如何根據1.的結果探討平均速度對時間的關係為何？
# 3.   如何根據2.的結˙果平均加速度對時間的關係為何？
#
# ## 位置與時間關係實驗
# ###活動目標
# 自長度為$L=1.00\,\text{m}$，高度為$h=0.10\,\text{m}$的斜面頂端一顆塑膠圓球自由地沿斜面滾下，並開始計時。在間隔$0.1\,\text{m}$的位置$x_i=0.1i, i=0,1,2,3,\cdots,10$，測量對應的時間$t_i$。

# %% [markdown]
# 將實驗數據輸入變數  x_data 及t_data

# %%
x_data=([0.00,0.10,0.2,0.30,0.40,0.50,0.60,0.70,0.80,0.90,1.00])
t_data=([0.00,0.44,0.63,0.77,0.89,1.00,1.09,1.18,1.26,1.34,1.41])

# %%
np.random.seed(1)
err_stdev = 0.05
# 生成均值为0，标准差为err_stdev为0.2的高斯噪声
t_noise = np.absolute(err_stdev*np.random.normal(size=len(x_data)))
t_noise
# Out:
# array([0.08121727, 0.03058782, 0.02640859, 0.05364843, 0.04327038,
#        0.11507693, 0.08724059, 0.03806035, 0.01595195, 0.01246852,
#        0.0731054 ])

# %% [markdown]
# 繪製$x-t$關係圖

# %%
xdata = np.asarray(t_data)
ydata = np.asarray(x_data)
xerror = np.asarray(t_noise)
plt.errorbar(xdata, ydata, yerr=0, xerr=xerror, fmt='none')
plt.plot(xdata, ydata, 'o')
plt.show()

# %% [markdown]
# ## 建立解釋模型
# 假設模型
#
#    model : $x=at^b$
#
#
# 分別對其進行最小平方擬合，計算其對應的卡方檢測量 $\chi^2$最小時的 $a, b$ 值。

# %% [markdown]
# 因為要配合下面使用的函數：
#  curve_fit(fun, xdata, ydata, sigama=ydata_error)
# *   假設 fun　的形式為 yth = fun(xdata, parameters)。
# *   函數 fun 的定義必須第一個參數為輸入 xdata,
# *   第二個為需要計算參數 parameters，並作為輸出資料。
# *   fun 根據定義的模型 $y=A*x^B $，
# *   依序將 xdata 中的數據讀入後，計算其理論值 $y_i=A*x_i^B $，
# *   第三個輸入 sigma=ydata_error, 其中 ydata_error為 ydata　的標準誤差。
# *   此函數乃利用最小平方法計算所謂的 $\chi^2$ 函數
# \begin{equation}
# \chi^2=\sum_{i=1}^{N}\frac{(f(\text{xdata}_i)-\text{ydada}_i)^2}{\text{ydata_error}_i^2}
# \end{equation}
# 的最小值，以得到函數中定義的模型參數 $A, B$。
# *   計算輸出：parameters, covariance
# *   parameters={A, B}:計算的參數的平均值
# *   covariance={c_{ii}}：參數的變異值

# %%
# Define the Model function
def Model(x, A, B):
    return  A*np.power(x,B)

# %% [markdown]
# 利用 curve_fit(fun, xdata, ydata) 函數根據計算數據的迴歸分析，回傳值為 parameters (決定的參數), covariance (誤差).

# %%
x_param, x_covar = curve_fit(Model, xdata, ydata)
print(x_param)
print(x_covar)
# Out:
# [0.50371751 1.99211208]
# [[ 5.93062283e-07 -3.48160870e-06]
#  [-3.48160870e-06  3.44769030e-05]]

# %%
t = np.linspace(0.01, 2, 100)
fit_x = Model(t, *x_param)
plt.errorbar(xdata, ydata, yerr=0, xerr=xerror, fmt='none')
plt.plot(xdata, ydata, 'o', label='data')
plt.plot(t, fit_x, '-', label='fit')
plt.legend()
plt.xlabel('time $t$')
plt.ylabel('position $x$')
plt.title('inclinde surface motion')
plt.show()

# %%
SE = np.sqrt(np.diag(x_covar))
SE_A = SE[0]
print(F'The value of A and B are {x_param[0]:.2f} and {x_param[1]:.2f} with standard error of {SE_A:.2f}.')
# Out:
# The value of A and B are 0.50 and 1.99 with standard error of 0.00.

# %% [markdown]
# ##  速度對時間的關係
# ### 活動目標
# 根據位置實驗數據，計算各段位移的平均速度，並根據平均速度等於初速與末速的平均，以及起初點的初速度為零等條件，逐段計算各位移終點的末速度。如此，終點速度的時間等於位移終點的時間。
# $$
# v_{avg}(t_i,t_{i+1})=\frac{v(t_i)+v(t_{i+1})}{2}
# $$
# $$
# v(t_{i+1})=v(t_i)+2v_{avg}(t_i,t_{i+1})
# $$

# %%
#定義 v_avg 及 tv_mid 矩陣
from scipy import interpolate
v_data=[]
tv_data=[]

for i in np.arange(10):
  del_x=x_data[i+1]-x_data[i]
  del_t=t_data[i+1]-t_data[i]
  v_data.append(del_x/del_t)
  tv_data.append((t_data[i+1]+t_data[i])/2)

v_data=np.asarray(v_data)
tv_data=np.asarray(tv_data)
print(v_data, tv_data)
# Out:
# [0.22727273 0.52631579 0.71428571 0.83333333 0.90909091 1.11111111
#  1.11111111 1.25       1.25       1.42857143] [0.22  0.535 0.7   0.83  0.945 1.045 1.135 1.22  1.3   1.375]

# %%
v_param, v_covar = curve_fit(Model, tv_data, v_data)
print(v_param)
print(v_covar)
# Out:
# [1.0055089 1.0091346]
# [[ 0.00018102 -0.00024714]
#  [-0.00024714  0.00252925]]

# %%
fit_v = Model(t, *v_param)
plt.plot(tv_data, v_data, 'o', label='data')
plt.plot(t, fit_v, '-', label='fit')
plt.legend()
plt.xlabel('time $t$')
plt.ylabel('velocity $v$')
plt.title('inclinde surface motion')
plt.show()

# %%
SE = np.sqrt(np.diag(v_covar))
SE_A = SE[0]
print(F'The value of A and B are {v_param[0]:.2f} and {v_param[1]:.2f} with standard error of {SE_A:.2f}.')
# Out:
# The value of A and B are 1.01 and 1.01 with standard error of 0.01.

# %% [markdown]
# 根據平均速度對時間的擬合公式，進一步優化平均速度數據，將中點時間帶入擬合公式以找出對應的平均速度。

# %%
#根據擬合公式，根據中點時間 tv_data 計算對應的 v_data
for i in np.arange(10):
  v_data[i]=v_param[0]*np.power(tv_data[i],v_param[1])

# %%
fit_v1 = Model(t, *v_param)
plt.plot(tv_data, v_data, 'o', label='data')
plt.plot(t, fit_v1, '-', label='fit')
plt.legend()
plt.xlabel('time $t$')
plt.ylabel('velocity $v$')
plt.title('inclinde surface motion')
plt.show()

# %% [markdown]
# ##加速度對時間的關係
# ### 活動目標
# 根據速度數據，計算各段位移的平均加速度，並計算其對應的中點時間

# %%
#定義 a_avg 及 ta_mid 矩陣
a_avg=[]
ta_mid=[]
for i in np.arange(9):
  del_v=v_data[i+1]-v_data[i]
  del_ta=tv_data[i+1]-tv_data[i]
  a_avg.append((del_v/del_ta))
  ta_mid.append((tv_data[i+1]+tv_data[i])/2)
a_avg=np.asarray(a_avg)
ta_mid=np.asarray(ta_mid)

# %%
a_param, a_covar = curve_fit(Model, ta_mid, a_avg)
print(a_param)
print(a_covar)
# Out:
# [1.01467898 0.00932145]
# [[3.45387790e-10 2.51640890e-10]
#  [2.51640890e-10 2.12031904e-09]]

# %%
fit_a = Model(t, *a_param)
pred_a = Model(t,v_param[0]*v_param[1],(v_param[1]-1))
plt.plot(ta_mid, a_avg, 'o', label='data')
plt.plot(t, fit_a, '-', label='fit') # fit of acceleration data
plt.plot(t, pred_a, '-', label='pred') # prediction from the v_fit model
plt.legend()
plt.xlabel('time $t$')
plt.ylabel('avaraged acceleration $a_avg$')
plt.title('inclinde surface motion')
plt.show()

# %%
SE = np.sqrt(np.diag(a_covar))
SE_A = SE[0]
print(F'The value of A and B are {a_param[0]:.2f} and {a_param[1]:.2f} with standard error of {SE_A:.2f}.')
# Out:
# The value of A and B are 1.01 and 0.01 with standard error of 0.00.

# %% [markdown]
# ## 結論
# ### 位移對時間關係
# 根據實驗數據得到的模型為
# $$ x(t)=0.50\times t^{1.99}$$
# 誤差 $0.00$
# ### 速度對時間關係
# 根據實驗數據得到的模型為
# $$ v(t)=1.01\times t^{1.01}$$
# 誤差 $0.01$
# ### 加速度對時間關係
# 根據實驗數據得到的模型為
# $$ a(t)= 1.01 \times t^{0.01}$$
# 誤差 $0.00$
#
# 因為誤差累加的關係，速度擬合的誤差 > 加速度擬合的誤差 = 位移擬合的誤差。
#
# ###加速度計算誤差改進原因分析
# 1.將平均速度的推論數據根據擬合公式重新計算中點時間對應的速度。
# 2.平均加速度的計算可視為根據平均速度的擬結果進行推論。
