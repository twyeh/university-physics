# %% [markdown]
# <a href="https://colab.research.google.com/github/twyeh/university-physics/blob/main/lcapy_Network_20240502.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pdflatex
# !sudo apt-get install texlive-latex-recommended
# !sudo apt install texlive-latex-extra
# !sudo apt install dvipng
# !pip install lcapy
# Out:
# ...
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.2.0
#     Uninstalling attrs-23.2.0:
#       Successfully uninstalled attrs-23.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fiona 1.9.6 requires attrs>=19.2.0, but you have attrs 18.2.0 which is incompatible.
# jsonschema 4.19.2 requires attrs>=22.2.0, but you have attrs 18.2.0 which is incompatible.
# referencing 0.35.0 requires attrs>=22.2.0, but you have attrs 18.2.0 which is incompatible.
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   dvisvgm fonts-droid-fallback fonts-lmodern fonts-noto-mono fonts-urw-base35
#   libfontenc1 libgs9 libgs9-common libidn12 libijs-0.35 libjbig2dec0
#   libkpathsea6 libptexenc1 libsynctex2 libteckit0 libtexlua53 libtexluajit2
# ...

# %%
from lcapy import R
R1=R(1e2)
R2=R(2e2)
Rtot=R1+R2
Rtot.draw()
Rtot.R
# Out:
# 300

# %%
from lcapy import R
R1=R(1e2)
R2=R(2e2)
Rtot=R1|R2
Rtot.draw()
Rtot.R
# Out:
# 200/3

# %%
from lcapy import R
R1=R(1e2)
R2=R(2e2)
R3=R(3e2)
Rtot=(R1+R2)|R3
Rtot.draw()
Rtot.R
# Out:
# 150

# %%
from lcapy import R
R1=R(1e2)
R2=R(2e2)
R3=R(3e2)
R4=R(4e2)
Rtot=(R1+R2)|(R3+R4)
Rtot.draw()
Rtot.R
# Out:
# 210

# %%
from lcapy import Circuit
Rtot=Circuit("""
P 0_1 0_2; right
W 0_1 0; right
W 0  1; up
W 0  4; down
R1 1 2 1e2; right
R2 2 3 2e2; right
R3 4 5 3e2; right
R4 5 6 4e2; right
R5 2 5 5e2; down
W 6 7; up
W 3 7; down
W 7 0_2; right
""")
Rtot.draw()
Rtot.simplify()
# Out:
# P 0_1 0_2; right
# W 0_1 0; right
# W 0 1; up
# W 0 4; down
# W 6 7; up
# W 3 7; down
# W 7 0_2; right
# W 4 5; right
# W 2 3; right
# Rt3 2 5 6000/37; down

# %%
from lcapy import Circuit
Rtot=Circuit("""
P 0_1 0_2;right
W 0_1 0; right
W 0  1; up
W 0  4; down
R1 1 2 1e2; right
R2 2 3 2e2; right
R3 4 5 3e2; right
R4 5 6 4e2; right
R6 2 5 6e2; down
W 6 7; up
W 3 7; down
W 7 0_2; right
W 0_1 8; down=2
V 8 9 9; right
W 9 0_2; up=2
W 0_1 10; up=2
R5 10 11 5e2; right
W 11 0_2; down=2
""")
Rtot.draw()

# %%
Rtot.R5.I
# Out:
# 9/500

# %%
Rtot.R1.I
# Out:
#  27
# ───
# 880

# %%
Rtot.R2.I
# Out:
# 261
# ────
# 8800

# %%
Rtot.R3.I
# Out:
#  27
# ────
# 2200

# %%
Rtot.R4.I
# Out:
# 117
# ────
# 8800

# %%
Rtot.R6.I
# Out:
# 9/8800

# %%
Itot=(Rtot.R3.I+Rtot.R1.I)+Rtot.R5.I
Itot
# Out:
#  1341
# ─────
# 22000

# %%
Rtot.V.v
# Out:
# 9

# %%
9*22000/1341
# Out:
# 147.6510067114094
